# %% [markdown]
# <a href="https://colab.research.google.com/github/Gitakamma/Pembelajaranmesin/blob/main/Tugas_1_Diabetes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/Testing.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              9      120             72             22       56  20.8
# 1              1       71             62              0        0  21.8
# 2              8       74             70             40       49  35.3
# 3              5       88             78             30        0  27.6
# 4             10      115             98              0        0  24.0
# ..           ...      ...            ...            ...      ...   ...
# 303           10      101             76             48      180  32.9
# 304            2      122             70             27        0  36.8
# 305            5      121             72             23      112  26.2
# 306            1      126             60              0        0  30.1
# 307            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.733   48        0
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            9      120             72             22       56  20.8
# 1            1       71             62              0        0  21.8
# 2            8       74             70             40       49  35.3
# 3            5       88             78             30        0  27.6
# 4           10      115             98              0        0  24.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.733   48        0
# 1                     0.416   26        0
# 2                     0.705   39        0
# 3                     0.258   37        0
# 4                     1.022   34        0

# %%
print(data.dtypes)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness   BMI  \
# 0              9      120             72             22  20.8
# 1              1       71             62              0  21.8
# 2              8       74             70             40  35.3
# 3              5       88             78             30  27.6
# 4             10      115             98              0  24.0
# ..           ...      ...            ...            ...   ...
# 303           10      101             76             48  32.9
# 304            2      122             70             27  36.8
# 305            5      121             72             23  26.2
# 306            1      126             60              0  30.1
# 307            1       93             70             31  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.733   48        0
# 1                       0.416   26        0
# 2                       0.705   39        0
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   308.000000  308.000000     308.000000     308.000000  308.000000
# mean      3.863636  119.983766      69.503247      20.694805   77.724026
# std       3.381437   31.186260      19.555067      16.298250  106.528025
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   97.750000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   17.000000
# 75%       6.000000  136.000000      80.000000      32.000000  127.750000
# max      13.000000  199.000000     114.000000      99.000000  600.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  308.000000                308.000000  308.000000  308.000000
# mean    31.865909                  0.445042   33.730519    0.301948
# std      7.427594                  0.297660   12.208374    0.459850
# ...

# %%
data.loc[:,"Glucose":].corr()
# Out:
#                            Glucose  BloodPressure  SkinThickness   Insulin  \
# Glucose                   1.000000       0.221150       0.113453  0.309074
# BloodPressure             0.221150       1.000000       0.242019  0.094094
# SkinThickness             0.113453       0.242019       1.000000  0.413319
# Insulin                   0.309074       0.094094       0.413319  1.000000
# BMI                       0.195295       0.322599       0.417625  0.199884
# DiabetesPedigreeFunction  0.086689       0.129540       0.207632  0.153375
# Age                       0.225663       0.291844      -0.080434 -0.118570
# Outcome                   0.479823       0.067085       0.100563  0.136689
#
#                                BMI  DiabetesPedigreeFunction       Age  \
# Glucose                   0.195295                  0.086689  0.225663
# BloodPressure             0.322599                  0.129540  0.291844
# SkinThickness             0.417625                  0.207632 -0.080434
# ...

# %%
# @title Pregnancies vs Glucose

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Pregnancies', y='Glucose', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Dengan API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-9db0c405-18eb-4176-b028-e6d5eb36b805" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9db0c405-18eb-4176-b028-e6d5eb36b805">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "diabetes"
# Out:
# ...
# ref                                               title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# akshaydattatraykhare/diabetes-dataset             Diabetes Dataset                                 9KB  2022-10-06 08:55:25          80377       1066  1.0
# mathchi/diabetes-data-set                         Diabetes Dataset                                 9KB  2020-08-05 21:27:01          90307        629  1.0
# imtkaggleteam/diabetes                            Diabetes                                        11KB  2023-10-08 11:40:36           1967         90  1.0
# uciml/pima-indians-diabetes-database              Pima Indians Diabetes Database                   9KB  2016-10-06 18:31:56         472803       4022  0.88235295
# ...

# %%
# !kaggle datasets download akshaydattatraykhare/diabetes-dataset
# Out:
# ...
#   0% 0.00/8.91k [00:00<?, ?B/s]
# 100% 8.91k/8.91k [00:00<00:00, 28.9MB/s]

# %%
# !unzip /content/diabetes-dataset.zip
# Out:
# Archive:  /content/diabetes-dataset.zip
#   inflating: diabetes.csv

# %%
pd.read_csv('/content/diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
